# %%
import googleapiclient.discovery
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine
import re
from googleapiclient.errors import HttpError

# %%
#using this to avoid creating duplicate values inside tables
mydb = mysql.connector.connect(host="localhost",user="root",password="")

mycursor = mydb.cursor(buffered=True)

mycursor.execute('drop database if exists youtube')

# %%
Api_key="AIzaSyBk8kv7gpUZmxyuNtaH1x6EiXqE-usA0mc"
api_service_name = "youtube"
api_version = "v3"
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=Api_key)

# %%
# mydb = mysql.connector.connect(host="localhost",user="root",password="")

# mycursor = mydb.cursor(buffered=True)
# mycursor.execute('drop table youtube.channels')

# %%
#fetching all the 10 channel details

def channel_data_df(channel_id):
    channel_ids=[]
    request = youtube.channels().list(
            part="contentDetails,snippet,statistics",
            id= channel_id
        )
    response = request.execute()

    data={ 'channel_id':channel_id,
            'channel_name':response['items'][0]['snippet']['title'], 
            'channel_des':response['items'][0]['snippet']['description'],
            'channel_playid':response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
            'channel_vidcount':response['items'][0]['statistics']['videoCount'],
            'channel_viewcount':response['items'][0]['statistics']['viewCount'],
            'channel_subcount':response['items'][0]['statistics']['subscriberCount']}
            
    df=pd.DataFrame(data,index=[0])

    return df

# %%
def allchanneldetails(channel_ids):
    mydb = mysql.connector.connect(host="localhost",user="root",password="")

    mycursor = mydb.cursor(buffered=True)

    db_connection_str = f"mysql+mysqlconnector://root@localhost/youtube"
    db_engine = create_engine(db_connection_str)


    mycursor.execute('create database if not exists youtube')
    mycursor.execute('USE youtube')
    mycursor.execute('''create table if not exists channels(channel_id VARCHAR(50), 
                    channel_name VARCHAR(100),channel_des TEXT, channel_playid VARCHAR(40), 
                    channel_vidcount INT(5), channel_viewcount INT(10), channel_subcount INT(10))''')
    mydb.commit()
    for channel_id in channel_ids:
        df=channel_data_df(channel_id)
        df.to_sql(name='channels', con=db_engine, if_exists='append', index=False)

    mycursor.close()
    mydb.close()
channel_ids = ['UCev07c8ykCOu-z84s61F2OA']
               #'UCpPOf9BQPwa4K11Zjxu1ZPw', 
                #'UCUgVpcNYpXUGT_c0NczH_tw', 
                #'UC65XjOZRGlsNmzWmX5fK6WA',
                #'UCpRLiwxTIGnp-k0DPKu3tcQ',
                #'UCrDPJnj_D5bIGgCZ2L3iWHQ',
                #'UC2Ck6EkS3RWIX86KsaHUHHw',
                #'UCvxYrWx7LaMbG2xGlI2tC1g',
                #'UCoPFNBECsd9cqpyV3QdQ8fw',
                #'UC5EQWvy59VeHPJz8mDALPxg']
allchanneldetails(channel_ids)

# %%
allchanneldetails(channel_ids)

# %%
# mydb = mysql.connector.connect(host="localhost",user="root",password="")

# mycursor = mydb.cursor(buffered=True)
# mycursor.execute('drop table youtube.videos')

# %%
#fetching all the video details available in all the 10 channels
def all_video_Ids(channel_ids):
    video_ids=[]
    for channel_id in channel_ids:
        #video_ids=[]
        response=youtube.channels().list(part="contentDetails",
                                         id= channel_id).execute()
        playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

        next_page_token=None
        
        while True:
            response1 = youtube.playlistItems().list(
                    part="contentDetails",
                    maxResults=50,
                    pageToken=next_page_token,
                    playlistId=playlist_id
                ).execute()
            for i in range(len(response1['items'])):
                video_ids.append(response1['items'][i]['contentDetails']['videoId'])
            next_page_token=response1.get('nextPageToken')

            if next_page_token is None:
                break
        #all_videoids.append(video_ids)        
    return video_ids
v_id=all_video_Ids(channel_ids)

# %%
v_id
# Out:
# ['QhONzt9vurs',
#  'wmWHuIiufc8',
#  'N8AX2XPh9ns',
#  '81RmmforpiI',
#  'uTOKs5RUxTI',
#  'uxAqSy0Qtr0',
#  'qsqIXB5NTmw',
#  'PV4gK-TfioM',
#  'g5ak0v8SvD8',
#  'StGtI_XJxXU',
#  'BqaQXD-nVpM',
#  '11MgqSpDLjI',
#  'ZvoAC8Zvl7o',
#  'go9GzeVWl4o',
#  'AHrXw7-z6EQ',
#  'FDzToPkXkM4',
#  '3CcY9jHE0_o',
#  '_cDfCBXlA9I',
#  '_sqjj8p98Hs',
#  '1JFc4XiM864',
#  'Rty-DOD3H2U',
#  'a_bONZ2rHtM',
#  '8xngqLwCGKk',
#  '9_FXKrozcQQ',
#  'pP0LpVh25nc',
#  'G_XJG76hUzs',
#  'd8zNkopssv4',
#  '5Q0TKu22sy0',
#  'PzhTGOFEy9E',
#  'KiXykEQzj28',
#  '3T_v-tIytvo',
#  'IN0I32PZy2Q',
#  'bvYW32ib_YM',
#  'GG-IHSczkZc',
#  'yzP7YzFQgUo',
#  '9HqcGw0tZj4',
#  '20m2IvpELJQ',
#  'H9z6_qAfZfA',
#  '7ytjQGX-nAI',
#  'sVMnx21LBnk',
#  'pgFBhPWWrxM',
#  'YsOINJ38FbA',
#  'xDuYrB8EscA',
#  'W93ig_8LRy4',
#  '5mXamk2p-Mc',
#  '-D2NYHIvMAg',
#  'sChLBSGkYL8',
#  'dCSPtpzR7wM',
#  'dV15Uyf_gvI',
#  'gH5ATThPz0c',
#  'bZ1WTgos00E',
#  '-9DZIeFDMD0',
#  'rPO4AgwFEs4',
#  'vJcR32g_v4o',
#  'Ax9n1x1fIWM',
#  'FDcfFXeCOGE',
#  'x8LLIPTqBaE',
#  'kNgI8DhotrE',
#  'k465_csHO3A',
#  '0rmRoa5ySdw',
#  'XoBkjgwlUoI',
#  '4p5X9Y9bE5E',
#  'gKSxobmY568',
#  'CZ82nYYpghw',
#  'fIAXm7aLI58',
#  'wxpGg9hHO8k',
#  'DZGf9jOgcm0',
#  'bXnKU7o9CSI']

# %%
def iso8601_duration_to_seconds(duration):
    match = re.match(r'^PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?$', duration)
    if not match:
        return None

    hours = int(match.group(1)) if match.group(1) else 0
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0

    total_seconds = (hours * 3600) + (minutes * 60) + seconds
    return total_seconds

# %%
def video_details_info_df(video_ids):
    video_data=[]
    for video_id in video_ids:
        request = youtube.videos().list(
                part="contentDetails,snippet,statistics",
                id=video_id
            )
        response = request.execute()

        for details in response["items"]:
            data= {'Video_Id':details['id'],
                'Video_title':details['snippet']['title'],
                'channel_id':details['snippet']['channelId'],
                'Video_Description':details['snippet']['description'],
                'Video_pubdate':details['snippet']['publishedAt'],
                'Video_thumbnails':details['snippet']['thumbnails']['default']['url'],
                'Video_viewcount':details['statistics']['viewCount'],
                'Video_likecount':details['statistics'].get('likeCount', 0),
                'Video_favoritecount':details['statistics']['favoriteCount'],
                'Video_commentcount':details['statistics'].get('commentCount', 0),
                'Video_duration':iso8601_duration_to_seconds(details['contentDetails']['duration']),
                'Video_caption':details['contentDetails']['caption']
            }

            video_data.append(data)

    df1=pd.DataFrame(video_data)
    return df1

# %%
video_details_info_df(v_id)
# Out:
#        Video_Id                                        Video_title  \
# 0   QhONzt9vurs  Ambedkar Ayya Birthday Song | Gana Chella Ambe...
# 1   wmWHuIiufc8  சீமான் தேர்தல் பாடல் | Seeman Election Song Mi...
# 2   N8AX2XPh9ns  Uyire ah Na Nanechan d Love Failure Gana Songs...
# 3   81RmmforpiI  Uyire ah Na Nanechan d Love Failure Gana Songs...
# 4   uTOKs5RUxTI  சீமான் செய்தியாளர் சந்திப்பின் போது இந்த பாடல்...
# ..          ...                                                ...
# 63  CZ82nYYpghw  Eanna Vettu Senra Penne Love Gana Rajan Song |...
# 64  fIAXm7aLI58  Majaula Ponna Katikuna Gana| Maja gana song | ...
# 65  wxpGg9hHO8k  Love gana song | Azaga Erukurea Vaza Marama Ra...
# 66  DZGf9jOgcm0  erangal gana | Naalu Perukku Nanri Rajan | Era...
# 67  bXnKU7o9CSI  Auna paduvana gana rajan | Jolly Gana Song | R...
#
#                   channel_id  \
# 0   UCev07c8ykCOu-z84s61F2OA
# 1   UCev07c8ykCOu-z84s61F2OA
# 2   UCev07c8ykCOu-z84s61F2OA
# 3   UCev07c8ykCOu-z84s61F2OA
# 4   UCev07c8ykCOu-z84s61F2OA
# ..                       ...
# 63  UCev07c8ykCOu-z84s61F2OA
# 64  UCev07c8ykCOu-z84s61F2OA
# 65  UCev07c8ykCOu-z84s61F2OA
# 66  UCev07c8ykCOu-z84s61F2OA
# 67  UCev07c8ykCOu-z84s61F2OA
#
#                                     Video_Description         Video_pubdate  \
# 0   #TrendingGana #Gana_Song  #ambedkar \n\nAMBEDK...  2024-04-13T10:30:14Z
# 1   #TrendingGana #Gana_Song \nSeeman 2024 Electio...  2024-04-08T07:30:11Z
# 2   #TrendingGana #Gana_Song  #FailureGana #failur...  2024-04-07T10:30:06Z
# 3   #TrendingGana #Gana_Song  #FailureGana #failur...  2024-04-04T16:30:02Z
# 4   சீமான் செய்தியாளர் சந்திப்பின் போது இந்த பாடல்...  2024-03-27T13:35:15Z
# ..                                                ...                   ...
# 63  #TRENDINGGANA\n\n\n\n #TrendingGana​ #DAMMUSON...  2021-03-23T06:30:19Z
# 64  #TRENDINGGANA\n\n\n\n #TrendingGana​ #DAMMUSON...  2021-03-23T06:29:49Z
# 65  #TrendingGana\n\n\n\n\n #TrendingGana​ #DAMMUS...  2021-03-23T06:27:33Z
# 66  #TrendingGana #erangalgana\n\n\n\n\n #Trending...  2021-03-23T06:26:37Z
# 67  #TrendingGana\n\n\n\n #TrendingGana​ #DAMMUSON...  2021-03-23T06:25:58Z
#
#                                   Video_thumbnails Video_viewcount  \
# 0   https://i.ytimg.com/vi/QhONzt9vurs/default.jpg            3223
# 1   https://i.ytimg.com/vi/wmWHuIiufc8/default.jpg            3782
# 2   https://i.ytimg.com/vi/N8AX2XPh9ns/default.jpg            2212
# 3   https://i.ytimg.com/vi/81RmmforpiI/default.jpg            1111
# 4   https://i.ytimg.com/vi/uTOKs5RUxTI/default.jpg           10616
# ..                                             ...             ...
# 63  https://i.ytimg.com/vi/CZ82nYYpghw/default.jpg            1056
# 64  https://i.ytimg.com/vi/fIAXm7aLI58/default.jpg            2158
# 65  https://i.ytimg.com/vi/wxpGg9hHO8k/default.jpg             633
# 66  https://i.ytimg.com/vi/DZGf9jOgcm0/default.jpg            1056
# 67  https://i.ytimg.com/vi/bXnKU7o9CSI/default.jpg             900
#
#    Video_likecount Video_favoritecount Video_commentcount  Video_duration  \
# 0              304                   0                 27             288
# 1              335                   0                  4              60
# 2               45                   0                  3             264
# 3               41                   0                  1              45
# 4              404                   0                 17              59
# ..             ...                 ...                ...             ...
# 63              37                   0                  0             275
# 64              64                   0                  1             202
# 65              19                   0                  0             174
# 66              13                   0                  0             268
# 67              30                   0                  0             209
#
#    Video_caption
# 0          false
# 1          false
# 2          false
# 3          false
# 4          false
# ..           ...
# 63         false
# 64         false
# 65         false
# 66         false
# 67         false
#
# [68 rows x 12 columns]

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database="youtube")

mycursor = mydb.cursor(buffered=True)

db_connection_str = f"mysql+mysqlconnector://root@localhost/youtube"
db_engine = create_engine(db_connection_str)

# %%
df1=video_details_info_df(v_id)
mydb = mysql.connector.connect(host="localhost",user="root",password="")

mycursor = mydb.cursor(buffered=True)

db_connection_str = f"mysql+mysqlconnector://root@localhost/youtube"
db_engine = create_engine(db_connection_str)
mycursor.execute('create database if not exists youtube')
mycursor.execute('USE youtube')
mycursor.execute('''create table if not exists videos (Video_Id VARCHAR(50),
                 Video_title TEXT, channel_id VARCHAR(50), Video_Description TEXT, Video_pubdate VARCHAR(30),
                 Video_thumbnails TEXT, Video_viewcount INT(15), Video_likecount INT(15),
                 Video_favoritecount INT(15), Video_commentcount INT(15), 
                 Video_duration VARCHAR(10), Video_caption VARCHAR(10)
                 ) ''')

mydb.commit()

df1.to_sql(name='videos', con=db_engine, if_exists='append', index=False)

mycursor.close()
mydb.close()

# %%
len(v_id)
# Out:
# 68

# %%
# mydb = mysql.connector.connect(host="localhost",user="root",password="")

# mycursor = mydb.cursor(buffered=True)
# mycursor.execute('drop table youtube.comments')

# %%
#fetching all the comments details from all the videos from all the 10 channels

def comment_details_info_df(video_ids):
    comment_data = []
    try:
        for video_id in video_ids:
            next_page_token = None
            while True:
                try:
                    request_comments = youtube.commentThreads().list(
                        part="snippet",
                        videoId=video_id,
                        maxResults=100,
                        pageToken=next_page_token)
                    response_comments = request_comments.execute()

                    for comment in response_comments["items"]:
                        data = {
                            'comment_id': comment['snippet']['topLevelComment']['id'],
                            'video_id': comment['snippet']['topLevelComment']['snippet']['videoId'],
                            'channel_id': comment['snippet']['channelId'],
                            'author_name': comment['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            'text_display': comment['snippet']['topLevelComment']['snippet']['textDisplay'],
                            'published_date': comment['snippet']['topLevelComment']['snippet']['publishedAt']
                        }
                        comment_data.append(data)

                    next_page_token = response_comments.get('nextPageToken')

                    if next_page_token is None:
                        break
                except HttpError as e:
                    if e.resp.status == 403:
                        print(f"Comments are disabled for video ID: {video_id}")
                        break
                    else:
                        raise
    except Exception as e:
        print(f"An error occurred: {e}")

    df2 = pd.DataFrame(comment_data)
    return df2

# %%
comment_details_info_df(v_id)
# Out:
#                       comment_id     video_id                channel_id  \
# 0     Ugww4zVacz3HLk2dxSZ4AaABAg  QhONzt9vurs  UCev07c8ykCOu-z84s61F2OA
# 1     Ugxf4bPsWYFw39GFx4F4AaABAg  QhONzt9vurs  UCev07c8ykCOu-z84s61F2OA
# 2     UgwUTriG25aT_kf6HD14AaABAg  QhONzt9vurs  UCev07c8ykCOu-z84s61F2OA
# 3     UgxgA-vOCpHL6Gy1vWl4AaABAg  QhONzt9vurs  UCev07c8ykCOu-z84s61F2OA
# 4     Ugzaf0_oWzSxIcve3Zp4AaABAg  QhONzt9vurs  UCev07c8ykCOu-z84s61F2OA
# ...                          ...          ...                       ...
# 2624  UgyLek6CQAAiaWxh-td4AaABAg  gKSxobmY568  UCev07c8ykCOu-z84s61F2OA
# 2625  Ugys7p546WkYAgfoRI54AaABAg  gKSxobmY568  UCev07c8ykCOu-z84s61F2OA
# 2626  UgzvslN-9U3b9BG4khF4AaABAg  gKSxobmY568  UCev07c8ykCOu-z84s61F2OA
# 2627  UgxZZzO59rX7ujTiscN4AaABAg  gKSxobmY568  UCev07c8ykCOu-z84s61F2OA
# 2628  UgyEY2yVg_44IlET0AJ4AaABAg  fIAXm7aLI58  UCev07c8ykCOu-z84s61F2OA
#
#                 author_name  \
# 0             @vignesharasu
# 1           @RamKumar-ih7ox
# 2             @elumalai7824
# 3     @venmalemanivelan2068
# 4       @jenishofficial5801
# ...                     ...
# 2624                @KGR143
# 2625        @unluckyboy2408
# 2626         @vaishnavi7884
# 2627       @poovaikalai6389
# 2628      @karthikaudio2815
#
#                                            text_display        published_date
# 0     Super bro 🙏🏻💪🏻💪🏻🙏🏻🙏🏻🙏🏻🙏🏻🙏🏻❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹...  2024-04-20T07:04:45Z
# 1                         Super Thala ❤️💯 jai Bheem 🙏🙏🙏  2024-04-15T02:54:06Z
# 2                                     Super thala... ❤🥰  2024-04-14T14:21:36Z
# 3     உண்மையில் நமது கடவுள் அண்ணல் அம்பேத்கர்<br>இந்...  2024-04-14T06:44:12Z
# 4     ஜெய் பீம் 🎉🎉🎉🎉🎉🇭🇹🇭🇹🇭🇹🇭🇹🇭🇹💙❤️👏👏👏🙏🙏🙏👍 சூப்பர்  த...  2024-04-13T18:19:13Z
# ...                                                 ...                   ...
# 2624  Vera vera Vera level bro  romba thanks bro, en...  2023-02-16T14:56:06Z
# 2625                                            🔥King 🔥  2021-09-26T18:03:16Z
# 2626                                   Super Rajan anna  2021-06-12T16:35:42Z
# 2627                                        Super rajan  2021-04-01T07:28:47Z
# 2628                                               👌👌👌👌  2022-07-15T16:29:15Z
#
# [2629 rows x 6 columns]

# %%
df2=comment_details_info_df(v_id)

mydb = mysql.connector.connect(host="localhost",user="root",password="")

mycursor = mydb.cursor(buffered=True)

db_connection_str = f"mysql+mysqlconnector://root@localhost/youtube"
db_engine = create_engine(db_connection_str)

mycursor.execute('USE youtube')
mycursor.execute('''create table if not exists comments (comment_id VARCHAR(30), video_id VARCHAR(15),
                channel_id VARCHAR(50),author_name LONGTEXT, text_display TEXT, published_date VARCHAR(20)
                ) ''')

mydb.commit()
df2.to_sql(name='comments', con=db_engine, if_exists='append', index=False)

mycursor.close()
mydb.close()

# %%
#selected 10 channel IDs
#'UCpPOf9BQPwa4K11Zjxu1ZPw'
#'UCUgVpcNYpXUGT_c0NczH_tw', 
#'UC65XjOZRGlsNmzWmX5fK6WA',
#'UCpRLiwxTIGnp-k0DPKu3tcQ',
#'UCev07c8ykCOu-z84s61F2OA',
#'UCrDPJnj_D5bIGgCZ2L3iWHQ',
#'UC2Ck6EkS3RWIX86KsaHUHHw',
#'UCvxYrWx7LaMbG2xGlI2tC1g',
#'UCoPFNBECsd9cqpyV3QdQ8fw',
#'UC5EQWvy59VeHPJz8mDALPxg'

# %%
1#What are the names of all the videos and their corresponding channels?

import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT videos.Video_title, channels.channel_name
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------------------------------------------------------------------------------------+----------------+
# | Video_title                                                                                            | channel_name   |
# |--------------------------------------------------------------------------------------------------------+----------------|
# | Ambedkar Ayya Birthday Song | Gana Chella Ambedkar Song |Jai Bhim| Ambedkar Gana Song |Trending Gana   | Trending Gana  |
# | Ambedkar Ayya Birthday Song | Gana Chella Ambedkar Song |Jai Bhim| Ambedkar Gana Song |Trending Gana   | Trending Gana  |
# | சீமான் தேர்தல் பாடல் | Seeman Election Song Mic Symbol Song   #seemanlive #ntk #seeman Trending Gana           | Trending Gana  |
# | சீமான் தேர்தல் பாடல் | Seeman Election Song Mic Symbol Song   #seemanlive #ntk #seeman Trending Gana           | Trending Gana  |
# | Uyire ah Na Nanechan d Love Failure Gana Songs | Unlucky Vinoth love failure song 4 k |Trending Gana   | Trending Gana  |
# | Uyire ah Na Nanechan d Love Failure Gana Songs | Unlucky Vinoth love failure song 4 k |Trending Gana   | Trending Gana  |
# | Uyire ah Na Nanechan d Love Failure Gana Songs | love failure song comming soon 4k |Trending Gana      | Trending Gana  |
# %%
2#Which channels have the most number of videos, and how many videos do they have?

import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT channel_name, COUNT(*) AS video_count
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
GROUP BY channel_name
ORDER BY video_count DESC
LIMIT 1;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+---------------+
# | channel_name   |   video_count |
# |----------------+---------------|
# | Trending Gana  |           136 |
# +----------------+---------------+

# %%
3#What are the top 10 most viewed videos and their respective channels?

import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT videos.Video_title, channels.channel_name
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
ORDER BY videos.Video_viewcount DESC
LIMIT 10;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------------------------------------------------------------------------------------------------------+----------------+
# | Video_title                                                                                           | channel_name   |
# |-------------------------------------------------------------------------------------------------------+----------------|
# | Ratha Kothippu Full Gana DJ Song New Version | Vangal Pulla💥Gana Vicky|dj remix gana | Trending Gana | Trending Gana  |
# | Ratha Kothippu Full Gana DJ Song New Version | Vangal Pulla💥Gana Vicky|dj remix gana | Trending Gana | Trending Gana  |
# | Mita So Joint So Gana Prabha Songs | Gana Prabha Ganja Song |கஞ்சா| Mitaso Jointso |Trending Gana       | Trending Gana  |
# | Mita So Joint So Gana Prabha Songs | Gana Prabha Ganja Song |கஞ்சா| Mitaso Jointso |Trending Gana       | Trending Gana  |
# | Varuva varuva Gana jp Dammu song| dammu kissa song | Kiruba Kiruba Gana song | |Trending Gana         | Trending Gana  |
# | Varuva varuva Gana jp Dammu song| dammu kissa song | Kiruba Kiruba Gana song | |Trending Gana         | Trending Gana  |
# | SIVAN GANJA GANA SONG | Andha Kadha Endha Kahdha Sondha Kadha Gana | Sivan ganja song |Trending Gana  | Trending Gana  |
# | SIVAN GANJA GANA SONG | Andha Kadha Endha Kahdha Sondha Kadha Gana | Sivan ganja song |Trending Gana  | Trending Gana  |
# | ButtRoad Sathish Dammu Full Song|Mulaiya Mayakkum Dammu Song| Dummuushtu ruppen Kissala |Trending Ga  | Trending Gana  |
# | ButtRoad Sathish Dammu Full Song|Mulaiya Mayakkum Dammu Song| Dummuushtu ruppen Kissala |Trending Ga  | Trending Gana  |
# +-------------------------------------------------------------------------------------------------------+----------------+

# %%
4# How many comments were made on each video, and what are their corresponding video names?

import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT videos.Video_title, COUNT(*) AS comment_count
FROM videos
JOIN comments ON videos.Video_Id = comments.video_id
GROUP BY videos.Video_title;
""")

data = mycursor.fetchall()

# | Varuva varuva Gana jp Dammu song| dammu kissa song | Kiruba Kiruba Gana song | |Trending Gana          |             195 |
# | Velankanni Matha Songs - Gana Burlo | Madha Amma 4K Song Trending Gana                                 |               4 |
# | சீமான் செய்தியாளர் சந்திப்பின் போது இந்த பாடல் ஒலித்தது #ntk #seeman #tnpolitics #tnelection2024                            |              13 |
# | சீமான் தேர்தல் பாடல் | Seeman Election Song Mic Symbol Song   #seemanlive #ntk #seeman Trending Gana           |               4 |
# +--------------------------------------------------------------------------------------------------------+-----------------+

# %%
5#Which videos have the highest number of likes, and what are their  corresponding channel names?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""

SELECT videos.Video_title, channels.channel_name
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
ORDER BY videos.Video_likecount DESC
LIMIT 1;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------------------------------------------------------------------------------------------------------+----------------+
# | Video_title                                                                                           | channel_name   |
# |-------------------------------------------------------------------------------------------------------+----------------|
# | Ratha Kothippu Full Gana DJ Song New Version | Vangal Pulla💥Gana Vicky|dj remix gana | Trending Gana | Trending Gana  |
# +-------------------------------------------------------------------------------------------------------+----------------+

# %%
6#What is the total number of likes for each video, and what are  their corresponding video names?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT videos.Video_title, SUM(videos.Video_likecount) AS total_likes
FROM videos
GROUP BY videos.Video_title;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------------------------------------------------------------------------------------+---------------+
# | Video_title                                                                                            |   total_likes |
# |--------------------------------------------------------------------------------------------------------+---------------|
# | Adiye Podi Echa Soru | அடியே போடி எச்ச சோறு | LOVE FAILURE SONG | 4K |Trending Gana                           |            44 |
# | Ambedkar Ayya Birthday Song | Gana Chella Ambedkar Song |Jai Bhim| Ambedkar Gana Song |Trending Gana   |           304 |
# | Amma gana song | amma feeling gana song |Amma Gana song Gana Jillu | TRENDING GANA                     |            44 |
# | Auna paduvana gana rajan | Jolly Gana Song | Rajan Gana Song | Trending Gana                           |            30 |
# | Awareness song  |Ganja Song Chinna Chinna Pasagalam Valikudhuga | Gana Saran Dammu Song |Trending      |           349 |
# | Awerness Dammu song | saidhapettai  Gana Jp  Awerness song Comming Soon 7305643081 |Trending Gana      |            98 |
# | Barbie Girl Song Tamil | Love Gana Song | Mangadu Gana Sathish Love Song |Trending Gana                |           362 |
# | ButtRoad Sathish Dammu Full Song|Mulaiya Mayakkum Dammu Song| Dummuushtu ruppen Kissala |Trending Ga   |         18348 |
# | ButtRoad Sathish Dammu Song |Mulaiya Mayakkum Dammu Song| New Ganja Gana Song |Trending Gana           |           601 |
# | Chennai gana | Robbery song | Loberyku Lobery Seivan Gana Rajan | TRENDING GANA                        |            46 |
# | Velankanni Matha Songs - Gana Burlo | Madha Amma 4K Song Trending Gana                                 |            73 |
# | சீமான் செய்தியாளர் சந்திப்பின் போது இந்த பாடல் ஒலித்தது #ntk #seeman #tnpolitics #tnelection2024                            |           404 |
# | சீமான் தேர்தல் பாடல் | Seeman Election Song Mic Symbol Song   #seemanlive #ntk #seeman Trending Gana           |           335 |
# +--------------------------------------------------------------------------------------------------------+---------------+

# %%
7#What is the total number of views for each channel, and what are their  corresponding channel names?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT channels.channel_name, SUM(videos.Video_viewcount) AS total_views
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
GROUP BY channels.channel_name;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+---------------+
# | channel_name   |   total_views |
# |----------------+---------------|
# | Trending Gana  |    3.9087e+07 |
# +----------------+---------------+

# %%
8#What are the names of all the channels that have published videos in the year 2022?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT DISTINCT channels.channel_name
FROM channels
JOIN videos ON channels.channel_id = videos.channel_id
WHERE YEAR(videos.Video_pubdate) = 2022;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+
# | channel_name   |
# |----------------|
# | Trending Gana  |
# +----------------+

# %%
9#What is the average duration of all videos in each channel, and what are their corresponding channel names?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT channels.channel_name, AVG(videos.Video_duration) AS average_duration
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
GROUP BY channels.channel_name;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+--------------------+
# | channel_name   |   average_duration |
# |----------------+--------------------|
# | Trending Gana  |            213.029 |
# +----------------+--------------------+

# %%
10#Which videos have the highest number of comments, and what are their corresponding channel names?
import mysql.connector

mydb = mysql.connector.connect(host="localhost", user="root", password="")
mycursor = mydb.cursor()

mycursor.execute('USE youtube')
mycursor.execute("""
SELECT videos.Video_title, channels.channel_name
FROM videos
JOIN channels ON videos.channel_id = channels.channel_id
ORDER BY videos.Video_commentcount DESC
LIMIT 1;
""")

data = mycursor.fetchall()

from tabulate import tabulate
print(tabulate(data,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------------------------------------------------------------------------------------------------------+----------------+
# | Video_title                                                                                           | channel_name   |
# |-------------------------------------------------------------------------------------------------------+----------------|
# | Ratha Kothippu Full Gana DJ Song New Version | Vangal Pulla💥Gana Vicky|dj remix gana | Trending Gana | Trending Gana  |
# +-------------------------------------------------------------------------------------------------------+----------------+
